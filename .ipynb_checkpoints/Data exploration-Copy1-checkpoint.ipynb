# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
# load dataset
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
datatypes = pd.DataFrame({'TrainDataType':train.dtypes,'TestDataType':test.dtypes}).reset_index()
datatypes
# Out:
#            index TrainDataType TestDataType
# 0       1stFlrSF         int64        int64
# 1       2ndFlrSF         int64        int64
# 2      3SsnPorch         int64        int64
# 3          Alley        object       object
# 4   BedroomAbvGr         int64        int64
# ..           ...           ...          ...
# 76     Utilities        object       object
# 77    WoodDeckSF         int64        int64
# 78     YearBuilt         int64        int64
# 79  YearRemodAdd         int64        int64
# 80        YrSold         int64        int64
#
# [81 rows x 3 columns]

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# list of numerical variables
numericalFeatures = [features for features in train.columns if train[features].dtype !='O']
print('Number of numerical variables: ', len(numericalFeatures))
# Out:
# Number of numerical variables:  38

# %%
# categorical variables
categoricalFeatures = [feature for feature in train.columns if train[feature].dtypes=='O']
print('Number of categorical variables: ', len(categoricalFeatures))
# Out:
# Number of categorical variables:  43

# %%
correlationDF = train.corr().sort_values(by=['SalePrice'], ascending=False)
correlationDF['SalePrice']
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
# check the distribution --> not surprised that it's not normal. We can fix it.
plt.hist(train['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
# try to normalize the data?

# %%
# missing data
total = train.isnull().sum().sort_values(ascending=False)
percent = (train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missingData = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

# %%
# dealing with missing data
train = train.drop((missingData[missingData['Total'] > 1]).index, 1)
train = train.drop(train.loc[train['Electrical'].isnull()].index)
train.isnull().sum().max()
# Out:
# 0

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
scaler = StandardScaler()
targetScaled = scaler.fit_transform(train['SalePrice'].to_numpy().reshape(-1, 1))
targetScaled
# Out:
# array([[ 0.34704187],
#        [ 0.0071701 ],
#        [ 0.53585953],
#        ...,
#        [ 1.07713679],
#        [-0.48847623],
#        [-0.42081658]])

# %%
# applying log transformation
train['SalePrice'] = np.log(train['SalePrice'])

# %%
#create column for new variable (one is enough because it's a binary categorical feature)
#if area>0 it gets 1, for area==0 it gets 0
train['HasBsmt'] = pd.Series(len(train['TotalBsmtSF']), index=train.index)
train['HasBsmt'] = 0 
train.loc[train['TotalBsmtSF']>0,'HasBsmt'] = 1
#transform data
train.loc[train['HasBsmt']==1,'TotalBsmtSF'] = np.log(train['TotalBsmtSF'])
# Out:
# d:\python\python36\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
train = pd.get_dummies(train)

# %%
train
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_ConLw  \
# ...

# %%
lr = LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(train, train['SalePrice'], test_size = 0.25, random_state = 0)

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = np.exp(lr.predict(X_test))
y_true = np.exp(y_test)

# %%
print("RMSE: ", np.sqrt(mean_squared_error(y_true, prediction)))
# Out:
# RMSE:  1.8926397612608325e-07

# %%
prediction
# Out:
# array([179900.00000005,  91299.99999999,  90000.00000006, 135959.99999983,
#        155999.99999987, 129999.99999989, 140999.99999996, 173999.99999993,
#         75000.        , 109007.99999992,  98299.9999998 , 324999.99999965,
#         90999.99999998, 226700.00000001, 301500.00000008, 154999.99999998,
#        173733.00000001, 415298.00000048, 281212.99999985, 177000.        ,
#        287000.00000058, 100000.00000002, 149350.00000002, 208899.99999995,
#         82500.00000003, 175000.00000004, 165000.00000026, 323999.99999993,
#         67000.00000007, 403000.00000002, 123599.99999994, 142499.99999996,
#        149899.99999991, 137899.99999984, 212900.00000016, 277499.99999968,
#         89470.99999995, 190000.00000006,  97000.00000006, 118999.99999998,
#        109999.99999992, 150999.99999981, 262999.99999992,  84500.00000001,
#        132499.9999999 , 242999.9999999 , 229999.99999996, 213489.99999992,
# ...
